# %% [markdown]
# #### Here we are going to extract the datasets and choose the columns we will work with

# %% [markdown]
# ## Importando bibliotecas que vamos usar e as tables que vamos usar
#
# ## botar os firts steps a cada passa shape.df por exemplo

# %%
import numpy as np
import pandas as pd

# importando dados sobre cada jogo da temporada 2018/2019 da premier league
matches_df = pd.read_csv("matches_info_df.csv", index_col=0)
matches_df
# Out:
#       timestamp               date_GMT    status  attendance  \
# 0    1533927600   Aug 10 2018 - 7:00pm  complete       74439
# 1    1533987000  Aug 11 2018 - 11:30am  complete       51749
# 2    1533996000   Aug 11 2018 - 2:00pm  complete       10353
# 3    1533996000   Aug 11 2018 - 2:00pm  complete       24821
# 4    1533996000   Aug 11 2018 - 2:00pm  complete       24121
# ..          ...                    ...       ...         ...
# 375  1557669600   May 12 2019 - 2:00pm  complete       53331
# 376  1557669600   May 12 2019 - 2:00pm  complete       74457
# 377  1557669600   May 12 2019 - 2:00pm  complete       30367
# 378  1557669600   May 12 2019 - 2:00pm  complete       60124
# 379  1557669600   May 12 2019 - 2:00pm  complete       20067
#
#         home_team_name           away_team_name          referee  Game Week  \
# 0    Manchester United           Leicester City   Andre Marriner          1
# 1     Newcastle United        Tottenham Hotspur  Martin Atkinson          1
# 2      AFC Bournemouth             Cardiff City     Kevin Friend          1
# 3               Fulham           Crystal Palace        Mike Dean          1
# 4    Huddersfield Town                  Chelsea   Chris Kavanagh          1
# ..                 ...                      ...              ...        ...
# 375          Liverpool  Wolverhampton Wanderers  Martin Atkinson         38
# 376  Manchester United             Cardiff City    Jonathan Moss         38
# 377        Southampton        Huddersfield Town      Lee Probert         38
# 378  Tottenham Hotspur                  Everton   Andre Marriner         38
# 379            Watford          West Ham United   Chris Kavanagh         38
#
#      Pre-Match PPG (Home)  Pre-Match PPG (Away)  ...  odds_ft_away_team_win  \
# 0                    0.00                  0.00  ...                   9.81
# 1                    0.00                  0.00  ...                   1.84
# 2                    0.00                  0.00  ...                   3.96
# 3                    0.00                  0.00  ...                   3.26
# 4                    0.00                  0.00  ...                   1.51
# ..                    ...                   ...  ...                    ...
# 375                  2.78                  1.28  ...                   9.00
# 376                  2.00                  0.61  ...                  10.00
# 377                  1.22                  0.33  ...                   7.50
# 378                  2.06                  1.06  ...                   3.55
# 379                  1.50                  1.00  ...                   3.10
#
#      odds_ft_over15  odds_ft_over25  odds_ft_over35  odds_ft_over45  \
# 0              1.33            2.00            3.60            7.50
# 1              1.31            1.95            3.50            5.75
# 2              1.31            1.95            3.45            6.70
# 3              1.28            1.87            3.20            7.00
# 4              1.29            1.91            3.30            6.95
# ..              ...             ...             ...             ...
# 375            1.18            1.57            2.45            4.75
# 376            1.12            1.41            2.00            3.60
# 377            1.19            1.61            2.50            4.75
# 378            1.22            1.71            2.80            6.00
# 379            1.16            1.54            2.35            4.00
#
#      odds_btts_yes  odds_btts_no  \
# 0             2.05          1.69
# 1             1.83          1.87
# 2             1.83          1.83
# 3             1.71          2.00
# 4             2.00          1.71
# ..             ...           ...
# 375           1.95          1.83
# 376           1.74          2.05
# 377           1.80          2.00
# 378           1.59          2.30
# 379           1.48          2.55
#
#                                           stadium_name  \
# 0                            Old Trafford (Manchester)
# 1                St. James' Park (Newcastle upon Tyne)
# 2               Vitality Stadium (Bournemouth- Dorset)
# 3                              Craven Cottage (London)
# 4    John Smith's Stadium (Huddersfield- West Yorks...
# ..                                                 ...
# 375                                Anfield (Liverpool)
# 376                          Old Trafford (Manchester)
# 377        St. Mary's Stadium (Southampton- Hampshire)
# 378                 Tottenham Hotspur Stadium (London)
# 379                            Vicarage Road (Watford)
#
#     home_team_shots_on_target_dirty dirty
# 0                               7.0     0
# 1                               3.0     0
# 2                               NaN     1
# 3                               NaN     1
# 4                               NaN     1
# ..                              ...   ...
# 375                             6.0     0
# 376                            11.0     0
# 377                             4.0     0
# 378                             4.0     0
# 379                             9.0     0
#
# [380 rows x 68 columns]

# %%
# importando table que vamos usar para complementar a analise dos dados com 
# informações das odds pre jogo
odds_df = pd.read_csv("https://raw.githubusercontent.com/gabrielaragao01/Data-Science-Project/main/data/raw/england-premier-league-2018-to-2019.csv")
odds_df.head()
# Out:
#   Div        Date      HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  10/08/2018    Man United       Leicester     2     1   H     1     0
# 1  E0  11/08/2018   Bournemouth         Cardiff     2     0   H     1     0
# 2  E0  11/08/2018        Fulham  Crystal Palace     0     2   A     0     1
# 3  E0  11/08/2018  Huddersfield         Chelsea     0     3   A     0     2
# 4  E0  11/08/2018     Newcastle       Tottenham     1     2   A     1     2
#
#   HTR  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 0   H  ...     1.79    17  -0.75     1.75     1.70     2.29     2.21  1.55
# 1   H  ...     1.83    20  -0.75     2.20     2.13     1.80     1.75  1.88
# 2   A  ...     1.87    22  -0.25     2.18     2.11     1.81     1.77  2.62
# 3   A  ...     1.84    23   1.00     1.84     1.80     2.13     2.06  7.24
# 4   A  ...     1.81    20   0.25     2.20     2.12     1.80     1.76  4.74
#
#    PSCD  PSCA
# 0  4.07  7.69
# 1  3.61  4.70
# 2  3.38  2.90
# 3  3.95  1.58
# 4  3.53  1.89
#
# [5 rows x 62 columns]

# %%
# adicionando tabela do final do campeonato
teams_stats = pd.read_csv("https://raw.githubusercontent.com/gabrielaragao01/Data-Science-Project/main/data/raw/england-premier-league-teams-2018-to-2019-stats.csv")
teams_stats
# Out:
#                      team_name              common_name     season  country  \
# 0                   Arsenal FC                  Arsenal  2018/2019  England
# 1         Tottenham Hotspur FC        Tottenham Hotspur  2018/2019  England
# 2           Manchester City FC          Manchester City  2018/2019  England
# 3            Leicester City FC           Leicester City  2018/2019  England
# 4            Crystal Palace FC           Crystal Palace  2018/2019  England
# 5                   Everton FC                  Everton  2018/2019  England
# 6                   Burnley FC                  Burnley  2018/2019  England
# 7               Southampton FC              Southampton  2018/2019  England
# 8              AFC Bournemouth          AFC Bournemouth  2018/2019  England
# 9         Manchester United FC        Manchester United  2018/2019  England
# 10                Liverpool FC                Liverpool  2018/2019  England
# 11                  Chelsea FC                  Chelsea  2018/2019  England
# 12          West Ham United FC          West Ham United  2018/2019  England
# 13                  Watford FC                  Watford  2018/2019  England
# 14         Newcastle United FC         Newcastle United  2018/2019  England
# 15             Cardiff City FC             Cardiff City  2018/2019    Wales
# 16                   Fulham FC                   Fulham  2018/2019  England
# 17   Brighton & Hove Albion FC   Brighton & Hove Albion  2018/2019  England
# 18        Huddersfield Town FC        Huddersfield Town  2018/2019  England
# 19  Wolverhampton Wanderers FC  Wolverhampton Wanderers  2018/2019  England
#
#     matches_played  matches_played_home  matches_played_away  \
# 0               38                   19                   19
# 1               38                   19                   19
# 2               38                   19                   19
# 3               38                   19                   19
# 4               38                   19                   19
# 5               38                   19                   19
# 6               38                   19                   19
# 7               38                   19                   19
# 8               38                   19                   19
# 9               38                   19                   19
# 10              38                   19                   19
# 11              38                   19                   19
# 12              38                   19                   19
# 13              38                   19                   19
# 14              38                   19                   19
# 15              38                   19                   19
# 16              38                   19                   19
# 17              38                   19                   19
# 18              38                   19                   19
# 19              38                   19                   19
#
#     suspended_matches  wins  wins_home  ...  goals_conceded_min_61_to_70  \
# 0                   0    21         14  ...                           12
# 1                   0    23         12  ...                            4
# 2                   0    32         18  ...                            4
# 3                   0    15          8  ...                            7
# 4                   0    14          5  ...                            8
# 5                   0    15         10  ...                           10
# 6                   0    11          7  ...                           10
# 7                   0     9          5  ...                            5
# 8                   0    13          8  ...                            8
# 9                   0    19         10  ...                            7
# 10                  0    30         17  ...                            3
# 11                  0    21         12  ...                            3
# 12                  0    15          9  ...                            5
# 13                  0    14          8  ...                            3
# 14                  0    12          8  ...                            3
# 15                  0    10          6  ...                           12
# 16                  0     7          6  ...                            8
# 17                  0     9          6  ...                            9
# 18                  0     3          2  ...                            7
# 19                  0    16         10  ...                            5
#
#     goals_conceded_min_71_to_80  goals_conceded_min_81_to_90  \
# 0                             1                            8
# 1                             8                           10
# 2                             2                            3
# 3                             1                            9
# 4                             8                           11
# 5                             5                            4
# 6                             4                           15
# 7                             4                           14
# 8                             6                           11
# 9                             7                            7
# 10                            3                            4
# 11                            4                            3
# 12                            6                           11
# 13                           12                            9
# 14                            6                           12
# 15                            3                           16
# 16                           10                           15
# 17                            9                            6
# 18                           13                           11
# 19                            7                            7
#
#     draw_percentage_overall  draw_percentage_home  draw_percentage_away  \
# 0                        18                    16                    21
# 1                         5                    11                     0
# 2                         5                     0                    11
# 3                        18                    16                    21
# 4                        18                    26                    11
# 5                        24                    21                    26
# 6                        18                    11                    26
# 7                        32                    42                    21
# 8                        16                    26                     5
# 9                        24                    32                    16
# 10                       18                    11                    26
# 11                       24                    32                    16
# 12                       18                    21                    16
# 13                       21                    16                    26
# 14                       24                     5                    42
# 15                       11                    11                    11
# 16                       13                    16                    11
# 17                       24                    26                    21
# 18                       18                    16                    21
# 19                       24                    21                    26
#
#     loss_percentage_ovearll  loss_percentage_home  loss_percentage_away  \
# 0                        26                    11                    42
# 1                        34                    26                    42
# 2                        11                     5                    16
# 3                        42                    42                    42
# 4                        45                    47                    42
# 5                        37                    26                    47
# 6                        53                    53                    53
# 7                        45                    32                    58
# 8                        50                    32                    68
# 9                        26                    16                    37
# 10                        3                     0                     5
# 11                       21                     5                    37
# 12                       42                    32                    53
# 13                       42                    42                    42
# 14                       45                    53                    37
# 15                       63                    58                    68
# 16                       68                    53                    84
# 17                       53                    42                    63
# 18                       74                    74                    74
# 19                       34                    26                    42
#
#     over145_corners_percentage
# 0                            5
# 1                           11
# 2                            5
# 3                            5
# 4                           11
# 5                           11
# 6                            0
# 7                            8
# 8                           11
# 9                            8
# 10                           5
# 11                           3
# 12                           5
# 13                           8
# 14                          16
# 15                          16
# 16                           8
# 17                           5
# 18                           0
# 19                           8
#
# [20 rows x 293 columns]

# %%
teams_stats = teams_stats[['common_name', 'performance_rank', 'shots_home', 'shots_on_target_home']]
teams_stats
# Out:
#                 common_name  performance_rank  shots_home  \
# 0                   Arsenal                 5         210
# 1         Tottenham Hotspur                 4         236
# 2           Manchester City                 1         307
# 3            Leicester City                 9         238
# 4            Crystal Palace                12         222
# 5                   Everton                 8         213
# 6                   Burnley                15         177
# 7               Southampton                16         207
# 8           AFC Bournemouth                14         191
# 9         Manchester United                 6         235
# 10                Liverpool                 2         267
# 11                  Chelsea                 3         242
# 12          West Ham United                10         204
# 13                  Watford                11         169
# 14         Newcastle United                13         213
# 15             Cardiff City                18         189
# 16                   Fulham                19         223
# 17   Brighton & Hove Albion                17         175
# 18        Huddersfield Town                20         169
# 19  Wolverhampton Wanderers                 7         219
#
#     shots_on_target_home
# 0                    116
# 1                    124
# 2                    167
# 3                    118
# 4                     94
# 5                    104
# 6                     85
# 7                    108
# 8                    100
# 9                    145
# 10                   145
# 11                   137
# 12                   107
# 13                   102
# 14                    98
# 15                    85
# 16                   101
# 17                    71
# 18                    77
# 19                   105

# %% [markdown]
# ## Deixando apenas os campos que vamos usar na analise (dropando o que nao vamos usar)

# %%
# definindo colunas que vamos usar:
matches_columns = ['date_GMT', 'home_team_name', 'away_team_name', 'Pre-Match PPG (Home)', 'Pre-Match PPG (Away)', 'home_team_goal_count', 'away_team_goal_count', 'home_team_goal_count_half_time', 'away_team_goal_count_half_time', 'home_team_goal_timings', 'away_team_goal_timings', 'home_team_shots', 'home_team_shots_on_target_original', 'home_team_shots_on_target_dirty', 'home_team_corner_count', 'away_team_shots', 'away_team_shots_on_target', 'away_team_corner_count', 'referee', 'home_team_yellow_cards', 'home_team_red_cards', 'away_team_yellow_cards', 'away_team_red_cards', 'home_team_fouls', 'away_team_fouls', 'dirty']

matches_df = matches_df[matches_columns]
matches_df
# Out:
#                   date_GMT     home_team_name           away_team_name  \
# 0     Aug 10 2018 - 7:00pm  Manchester United           Leicester City
# 1    Aug 11 2018 - 11:30am   Newcastle United        Tottenham Hotspur
# 2     Aug 11 2018 - 2:00pm    AFC Bournemouth             Cardiff City
# 3     Aug 11 2018 - 2:00pm             Fulham           Crystal Palace
# 4     Aug 11 2018 - 2:00pm  Huddersfield Town                  Chelsea
# ..                     ...                ...                      ...
# 375   May 12 2019 - 2:00pm          Liverpool  Wolverhampton Wanderers
# 376   May 12 2019 - 2:00pm  Manchester United             Cardiff City
# 377   May 12 2019 - 2:00pm        Southampton        Huddersfield Town
# 378   May 12 2019 - 2:00pm  Tottenham Hotspur                  Everton
# 379   May 12 2019 - 2:00pm            Watford          West Ham United
#
#      Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_team_goal_count  \
# 0                    0.00                  0.00                     2
# 1                    0.00                  0.00                     1
# 2                    0.00                  0.00                     2
# 3                    0.00                  0.00                     0
# 4                    0.00                  0.00                     0
# ..                    ...                   ...                   ...
# 375                  2.78                  1.28                     2
# 376                  2.00                  0.61                     0
# 377                  1.22                  0.33                     1
# 378                  2.06                  1.06                     2
# 379                  1.50                  1.00                     1
#
#      away_team_goal_count  home_team_goal_count_half_time  \
# 0                       1                               1
# 1                       2                               1
# 2                       0                               1
# 3                       2                               0
# 4                       3                               0
# ..                    ...                             ...
# 375                     0                               1
# 376                     2                               0
# 377                     1                               1
# 378                     2                               1
# 379                     4                               0
#
#      away_team_goal_count_half_time home_team_goal_timings  ...  \
# 0                                 0                   3,83  ...
# 1                                 2                     11  ...
# 2                                 0                24,90'1  ...
# 3                                 1                    NaN  ...
# 4                                 2                    NaN  ...
# ..                              ...                    ...  ...
# 375                               0                  17,81  ...
# 376                               1                    NaN  ...
# 377                               0                     41  ...
# 378                               0                   3,75  ...
# 379                               2                     46  ...
#
#     away_team_shots_on_target  away_team_corner_count          referee  \
# 0                           5                       5   Andre Marriner
# 1                           6                       5  Martin Atkinson
# 2                           2                       4     Kevin Friend
# 3                          11                       5        Mike Dean
# 4                           5                       5   Chris Kavanagh
# ..                        ...                     ...              ...
# 375                         3                       1  Martin Atkinson
# 376                         5                       2    Jonathan Moss
# 377                         4                       3      Lee Probert
# 378                        10                       4   Andre Marriner
# 379                        10                       2   Chris Kavanagh
#
#      home_team_yellow_cards  home_team_red_cards  away_team_yellow_cards  \
# 0                         2                    0                       1
# 1                         2                    0                       2
# 2                         1                    0                       1
# 3                         1                    0                       2
# 4                         2                    0                       1
# ..                      ...                  ...                     ...
# 375                       0                    0                       2
# 376                       3                    0                       3
# 377                       0                    0                       1
# 378                       0                    0                       2
# 379                       1                    1                       0
#
#      away_team_red_cards  home_team_fouls away_team_fouls  dirty
# 0                      0               11               8      0
# 1                      0               11              12      0
# 2                      0               11               9      1
# 3                      0                9              11      1
# 4                      0                9               8      1
# ..                   ...              ...             ...    ...
# 375                    0                3              11      0
# 376                    0                9               6      0
# 377                    0                8               6      0
# 378                    0               10              13      0
# 379                    0               10              10      0
#
# [380 rows x 26 columns]

# %%
odds_columns = ['HomeTeam', 'AwayTeam', 'B365H', 'B365D', 'B365A']

odds_df = odds_df[odds_columns]
odds_df
# Out:
#          HomeTeam        AwayTeam  B365H  B365D  B365A
# 0      Man United       Leicester   1.57   3.90   7.50
# 1     Bournemouth         Cardiff   1.90   3.60   4.50
# 2          Fulham  Crystal Palace   2.50   3.40   3.00
# 3    Huddersfield         Chelsea   6.50   4.00   1.61
# 4       Newcastle       Tottenham   3.90   3.50   2.04
# ..            ...             ...    ...    ...    ...
# 375     Liverpool          Wolves   1.30   6.00  11.00
# 376    Man United         Cardiff   1.28   6.50  11.00
# 377   Southampton    Huddersfield   1.44   4.75   8.50
# 378     Tottenham         Everton   2.20   3.50   3.50
# 379       Watford        West Ham   2.25   3.75   3.20
#
# [380 rows x 5 columns]

# %% [markdown]
# ## Vamos juntar os dois data frames, matches e odds, para podermos saber como estao as espectativas pre jogo

# %%
# primeiro precisamos unificar os nomes dos times
#que estao diferentes em ambos os data frames

# Renomear as colunas em odds_df para corresponder às colunas em data
odds_df = odds_df.rename(columns={
    'HomeTeam': 'home_team_name',
    'AwayTeam': 'away_team_name',
})

# Criar um dicionário de mapeamento para padronizar os nomes dos times
team_name_mapping = {
    'Man United': 'Manchester United',
    'Man City': 'Manchester City',
    'Leicester': 'Leicester City',
    'Newcastle': 'Newcastle United',
    'Bournemouth': 'AFC Bournemouth',
    'Brighton': 'Brighton & Hove Albion',
    'Wolves': 'Wolverhampton Wanderers',
    'West Ham': 'West Ham United',
    'Cardiff': 'Cardiff City',
    'Tottenham': 'Tottenham Hotspur',
    'Huddersfield': 'Huddersfield Town',
}


# Aplicar o mapeamento aos DataFrames
matches_df['home_team_name'] = matches_df['home_team_name'].replace(team_name_mapping)
matches_df['away_team_name'] = matches_df['away_team_name'].replace(team_name_mapping)
odds_df['home_team_name'] = odds_df['home_team_name'].replace(team_name_mapping)
odds_df['away_team_name'] = odds_df['away_team_name'].replace(team_name_mapping)

# Realizar a junção dos DataFrames com base nos nomes padronizados dos times
matches_info_df = pd.merge(matches_df, odds_df, on=['home_team_name', 'away_team_name'], how='inner')
matches_info_df
# Out:
# C:\Users\diogo\AppData\Local\Temp\ipykernel_18732\2869944098.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches_df['home_team_name'] = matches_df['home_team_name'].replace(team_name_mapping)
# C:\Users\diogo\AppData\Local\Temp\ipykernel_18732\2869944098.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches_df['away_team_name'] = matches_df['away_team_name'].replace(team_name_mapping)
#                   date_GMT     home_team_name           away_team_name  \
# 0     Aug 10 2018 - 7:00pm  Manchester United           Leicester City
# 1    Aug 11 2018 - 11:30am   Newcastle United        Tottenham Hotspur
# 2     Aug 11 2018 - 2:00pm    AFC Bournemouth             Cardiff City
# 3     Aug 11 2018 - 2:00pm             Fulham           Crystal Palace
# 4     Aug 11 2018 - 2:00pm  Huddersfield Town                  Chelsea
# ..                     ...                ...                      ...
# 375   May 12 2019 - 2:00pm          Liverpool  Wolverhampton Wanderers
# 376   May 12 2019 - 2:00pm  Manchester United             Cardiff City
# 377   May 12 2019 - 2:00pm        Southampton        Huddersfield Town
# 378   May 12 2019 - 2:00pm  Tottenham Hotspur                  Everton
# 379   May 12 2019 - 2:00pm            Watford          West Ham United
#
#      Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_team_goal_count  \
# 0                    0.00                  0.00                     2
# 1                    0.00                  0.00                     1
# 2                    0.00                  0.00                     2
# 3                    0.00                  0.00                     0
# 4                    0.00                  0.00                     0
# ..                    ...                   ...                   ...
# 375                  2.78                  1.28                     2
# 376                  2.00                  0.61                     0
# 377                  1.22                  0.33                     1
# 378                  2.06                  1.06                     2
# 379                  1.50                  1.00                     1
#
#      away_team_goal_count  home_team_goal_count_half_time  \
# 0                       1                               1
# 1                       2                               1
# 2                       0                               1
# 3                       2                               0
# 4                       3                               0
# ..                    ...                             ...
# 375                     0                               1
# 376                     2                               0
# 377                     1                               1
# 378                     2                               1
# 379                     4                               0
#
#      away_team_goal_count_half_time home_team_goal_timings  ...  \
# 0                                 0                   3,83  ...
# 1                                 2                     11  ...
# 2                                 0                24,90'1  ...
# 3                                 1                    NaN  ...
# 4                                 2                    NaN  ...
# ..                              ...                    ...  ...
# 375                               0                  17,81  ...
# 376                               1                    NaN  ...
# 377                               0                     41  ...
# 378                               0                   3,75  ...
# 379                               2                     46  ...
#
#     home_team_yellow_cards  home_team_red_cards  away_team_yellow_cards  \
# 0                        2                    0                       1
# 1                        2                    0                       2
# 2                        1                    0                       1
# 3                        1                    0                       2
# 4                        2                    0                       1
# ..                     ...                  ...                     ...
# 375                      0                    0                       2
# 376                      3                    0                       3
# 377                      0                    0                       1
# 378                      0                    0                       2
# 379                      1                    1                       0
#
#      away_team_red_cards  home_team_fouls  away_team_fouls  dirty  B365H  \
# 0                      0               11                8      0   1.57
# 1                      0               11               12      0   3.90
# 2                      0               11                9      1   1.90
# 3                      0                9               11      1   2.50
# 4                      0                9                8      1   6.50
# ..                   ...              ...              ...    ...    ...
# 375                    0                3               11      0   1.30
# 376                    0                9                6      0   1.28
# 377                    0                8                6      0   1.44
# 378                    0               10               13      0   2.20
# 379                    0               10               10      0   2.25
#
#     B365D  B365A
# 0    3.90   7.50
# 1    3.50   2.04
# 2    3.60   4.50
# 3    3.40   3.00
# 4    4.00   1.61
# ..    ...    ...
# 375  6.00  11.00
# 376  6.50  11.00
# 377  4.75   8.50
# 378  3.50   3.50
# 379  3.75   3.20
#
# [380 rows x 29 columns]

# %%
def checking_result(row):
    result = row['home_team_goal_count'] - row['away_team_goal_count']
        
    return result

# defining the result
matches_info_df['result'] = matches_info_df.apply(checking_result, axis=1)

# Divide the season into three parts based on index position
matches_info_df["season_part"] = 'first'
matches_info_df.loc[(matches_info_df.index > 120) & (matches_info_df.index < 240),'season_part'] = 'mid'
matches_info_df.loc[(matches_info_df.index >= 240),'season_part'] = 'last'

# Converting the 'match_datetime' column to datetime format
matches_info_df['match_datetime'] = pd.to_datetime(matches_info_df['date_GMT'], format='%b %d %Y - %I:%M%p')
# Creating the 'day_or_night' column based on the hour of the match
matches_info_df['day_or_night'] = matches_info_df['match_datetime'].dt.hour.apply(lambda x: 'Night' if x >= 17 else 'Day')

def home_second_half_goals(row):
    home_goals_second_half = row['home_team_goal_count'] - row['home_team_goal_count_half_time']
    
    return int(home_goals_second_half)

def away_second_half_goals(row):
    away_goals_second_half = row['away_team_goal_count'] - row['away_team_goal_count_half_time']
    
    return int(away_goals_second_half)

# creating column to goals on 2 half
matches_info_df['home_team_goal_count_secondhalf_time'] = matches_info_df.apply(home_second_half_goals, axis=1)
matches_info_df['away_team_goal_count_secondhalf_time'] = matches_info_df.apply(away_second_half_goals, axis=1)

# Function to verify if there are goals scored after the 80th minute for both teams
def has_goals_after_80_minutes(row):
    home_goals = row['home-80-final']
    away_goals = row['away-80-final']
    
    return home_goals or away_goals

# Function to convert time notation to minutes
def convert_time_notation_to_minutes(time_str):
    values = time_str.split("'")
    if len(values) != 1 and len(values) != 2:
        raise Exception('Invalid time notation')

    minutes = int(values[0])
    if len(values) == 2:
        minutes += int(values[1])

    return minutes

# Function to check if there are goals scored after a specified threshold time
def has_goals_after_threshold(times_str, threshold=80):
    # Splitting the goal timings string using comma delimiter
    timings_arr = times_str.split(',')
    # Converting time notation to minutes
    minutes_arr = [convert_time_notation_to_minutes(x) for x in timings_arr]

    # Checking if any time is greater than or equal to the threshold
    for time in minutes_arr:
        if time >= threshold:
            return True
    
    return False

# Applying the has_goals_after_threshold function to home and away goal timings, and combining the results
matches_info_df['home-80-final'] = matches_info_df['home_team_goal_timings'].apply(lambda x: has_goals_after_threshold(x) if not isinstance(x, float) else False)
matches_info_df['away-80-final'] = matches_info_df['away_team_goal_timings'].apply(lambda x: has_goals_after_threshold(x) if not isinstance(x, float) else False)
matches_info_df['80-final'] = matches_info_df.apply(has_goals_after_80_minutes, axis=1)

# Selecting relevant columns for analysis
matches_info_df[['home_team_goal_timings', 'away_team_goal_timings', 'home-80-final', 'away-80-final', '80-final', 'home_team_goal_count_secondhalf_time']].head(20)
# Out:
#    home_team_goal_timings away_team_goal_timings  home-80-final  \
# 0                    3,83                   90'2           True
# 1                      11                   8,18          False
# 2                 24,90'1                    NaN           True
# 3                     NaN                  41,79          False
# 4                     NaN               34,45,80          False
# 5                   35,54                    NaN          False
# 6                   44,80                  17,67           True
# 7           19,45'2,53,88                    NaN           True
# 8                     NaN                    NaN          False
# 9                     NaN                  14,64          False
# 10                    NaN                    NaN          False
# 11                  15,31                     54          False
# 12                  29,45                    NaN          False
# 13               43,74,77                     52          False
# 14                     33                  60,66          False
# 15                9,20,81                  37,41           True
# 16                      6                3,48,51          False
# 17      25,31,35,48,75,84                     43           True
# 18               25,27,44                34,90'5          False
# 19                    NaN                45,90'3          False
#
#     away-80-final  80-final  home_team_goal_count_secondhalf_time
# 0            True      True                                     1
# 1           False     False                                     0
# 2           False      True                                     1
# 3           False     False                                     0
# 4            True      True                                     0
# 5           False     False                                     1
# 6           False      True                                     1
# 7           False      True                                     2
# 8           False     False                                     0
# 9           False     False                                     0
# 10          False     False                                     0
# 11          False     False                                     0
# 12          False     False                                     0
# 13          False     False                                     2
# 14          False     False                                     0
# 15          False      True                                     1
# 16          False     False                                     0
# 17          False      True                                     3
# 18           True      True                                     0
# 19           True      True                                     0

# %%
# Adicionar coluna de índice original ao DataFrame matches_info_df
matches_info_df['original_index'] = matches_info_df.index

# Realizar a junção dos DataFrames com base nos nomes padronizados dos times
teams_stats.rename(columns={'common_name': 'home_team_name', 'shots_home': 'home_season_shots', 'shots_on_target_home': 'home_season_shots_on_target', 'performance_rank': 'performance_rank_home'}, inplace=True)
matches_info_df = pd.merge(matches_info_df, teams_stats, on=['home_team_name'], how='inner')

teams_stats = teams_stats.drop(columns=['home_season_shots', 'home_season_shots_on_target'])
teams_stats.rename(columns={'home_team_name': 'away_team_name', 'performance_rank_home': 'away_performance_rank'}, inplace=True)
matches_info_df = pd.merge(matches_info_df, teams_stats, on=['away_team_name'], how='inner')

# Ordenar pelo índice original para manter a ordem das linhas
matches_info_df = matches_info_df.sort_values(by='original_index').reset_index(drop=True)

# Remover a coluna de índice original
matches_info_df = matches_info_df.drop(columns=['original_index'])

matches_info_df

# falar com o professor para ver se isso aqui é merda
# Out:
# C:\Users\diogo\AppData\Local\Temp\ipykernel_18732\3360590284.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teams_stats.rename(columns={'common_name': 'home_team_name', 'shots_home': 'home_season_shots', 'shots_on_target_home': 'home_season_shots_on_target', 'performance_rank': 'performance_rank_home'}, inplace=True)
#                   date_GMT     home_team_name           away_team_name  \
# 0     Aug 10 2018 - 7:00pm  Manchester United           Leicester City
# 1    Aug 11 2018 - 11:30am   Newcastle United        Tottenham Hotspur
# 2     Aug 11 2018 - 2:00pm    AFC Bournemouth             Cardiff City
# 3     Aug 11 2018 - 2:00pm             Fulham           Crystal Palace
# 4     Aug 11 2018 - 2:00pm  Huddersfield Town                  Chelsea
# ..                     ...                ...                      ...
# 375   May 12 2019 - 2:00pm          Liverpool  Wolverhampton Wanderers
# 376   May 12 2019 - 2:00pm  Manchester United             Cardiff City
# 377   May 12 2019 - 2:00pm        Southampton        Huddersfield Town
# 378   May 12 2019 - 2:00pm  Tottenham Hotspur                  Everton
# 379   May 12 2019 - 2:00pm            Watford          West Ham United
#
#      Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_team_goal_count  \
# 0                    0.00                  0.00                     2
# 1                    0.00                  0.00                     1
# 2                    0.00                  0.00                     2
# 3                    0.00                  0.00                     0
# 4                    0.00                  0.00                     0
# ..                    ...                   ...                   ...
# 375                  2.78                  1.28                     2
# 376                  2.00                  0.61                     0
# 377                  1.22                  0.33                     1
# 378                  2.06                  1.06                     2
# 379                  1.50                  1.00                     1
#
#      away_team_goal_count  home_team_goal_count_half_time  \
# 0                       1                               1
# 1                       2                               1
# 2                       0                               1
# 3                       2                               0
# 4                       3                               0
# ..                    ...                             ...
# 375                     0                               1
# 376                     2                               0
# 377                     1                               1
# 378                     2                               1
# 379                     4                               0
#
#      away_team_goal_count_half_time home_team_goal_timings  ... day_or_night  \
# 0                                 0                   3,83  ...        Night
# 1                                 2                     11  ...          Day
# 2                                 0                24,90'1  ...          Day
# 3                                 1                    NaN  ...          Day
# 4                                 2                    NaN  ...          Day
# ..                              ...                    ...  ...          ...
# 375                               0                  17,81  ...          Day
# 376                               1                    NaN  ...          Day
# 377                               0                     41  ...          Day
# 378                               0                   3,75  ...          Day
# 379                               2                     46  ...          Day
#
#      home_team_goal_count_secondhalf_time  \
# 0                                       1
# 1                                       0
# 2                                       1
# 3                                       0
# 4                                       0
# ..                                    ...
# 375                                     1
# 376                                     0
# 377                                     0
# 378                                     1
# 379                                     1
#
#      away_team_goal_count_secondhalf_time  home-80-final  away-80-final  \
# 0                                       1           True           True
# 1                                       0          False          False
# 2                                       0           True          False
# 3                                       1          False          False
# 4                                       1          False           True
# ..                                    ...            ...            ...
# 375                                     0           True          False
# 376                                     1          False          False
# 377                                     1          False          False
# 378                                     2          False          False
# 379                                     2          False          False
#
#      80-final  performance_rank_home  home_season_shots  \
# 0        True                      6                235
# 1       False                     13                213
# 2        True                     14                191
# 3       False                     19                223
# 4        True                     20                169
# ..        ...                    ...                ...
# 375      True                      2                267
# 376     False                      6                235
# 377     False                     16                207
# 378     False                      4                236
# 379     False                     11                169
#
#     home_season_shots_on_target  away_performance_rank
# 0                           145                      9
# 1                            98                      4
# 2                           100                     18
# 3                           101                     12
# 4                            77                      3
# ..                          ...                    ...
# 375                         145                      7
# 376                         145                     18
# 377                         108                     20
# 378                         124                      8
# 379                         102                     10
#
# [380 rows x 42 columns]

# %%
## colocando as colunas na ordem correta
ordered_df = ['result', 'performance_rank_home', 'home_team_name','B365H', 'B365D', 'B365A', 'away_team_name', 'away_performance_rank',  'Pre-Match PPG (Home)', 'Pre-Match PPG (Away)', 'home_team_goal_count', 'away_team_goal_count', 'home_team_goal_count_half_time', 'home_team_goal_count_secondhalf_time', 'away_team_goal_count_half_time','away_team_goal_count_secondhalf_time', 'home_team_goal_timings', 'away_team_goal_timings', 'home_team_shots', 'home_team_shots_on_target_original', 'home_team_corner_count', 'home_team_shots_on_target_dirty','away_team_shots', 'away_team_shots_on_target', 'away_team_corner_count', 'season_part', 'day_or_night', 'home-80-final', 'away-80-final', '80-final', 'home_season_shots', 'home_season_shots_on_target', 'referee', 'home_team_yellow_cards', 'home_team_red_cards', 'away_team_yellow_cards', 'away_team_red_cards', 'home_team_fouls', 'away_team_fouls', 'dirty']

matches_info_df = matches_info_df[ordered_df]
matches_info_df.to_csv('matches_info_df.csv')
matches_info_df
# Out:
#      result  performance_rank_home     home_team_name  B365H  B365D  B365A  \
# 0         1                      6  Manchester United   1.57   3.90   7.50
# 1        -1                     13   Newcastle United   3.90   3.50   2.04
# 2         2                     14    AFC Bournemouth   1.90   3.60   4.50
# 3        -2                     19             Fulham   2.50   3.40   3.00
# 4        -3                     20  Huddersfield Town   6.50   4.00   1.61
# ..      ...                    ...                ...    ...    ...    ...
# 375       2                      2          Liverpool   1.30   6.00  11.00
# 376      -2                      6  Manchester United   1.28   6.50  11.00
# 377       0                     16        Southampton   1.44   4.75   8.50
# 378       0                      4  Tottenham Hotspur   2.20   3.50   3.50
# 379      -3                     11            Watford   2.25   3.75   3.20
#
#               away_team_name  away_performance_rank  Pre-Match PPG (Home)  \
# 0             Leicester City                      9                  0.00
# 1          Tottenham Hotspur                      4                  0.00
# 2               Cardiff City                     18                  0.00
# 3             Crystal Palace                     12                  0.00
# 4                    Chelsea                      3                  0.00
# ..                       ...                    ...                   ...
# 375  Wolverhampton Wanderers                      7                  2.78
# 376             Cardiff City                     18                  2.00
# 377        Huddersfield Town                     20                  1.22
# 378                  Everton                      8                  2.06
# 379          West Ham United                     10                  1.50
#
#      Pre-Match PPG (Away)  ...  home_season_shots  \
# 0                    0.00  ...                235
# 1                    0.00  ...                213
# 2                    0.00  ...                191
# 3                    0.00  ...                223
# 4                    0.00  ...                169
# ..                    ...  ...                ...
# 375                  1.28  ...                267
# 376                  0.61  ...                235
# 377                  0.33  ...                207
# 378                  1.06  ...                236
# 379                  1.00  ...                169
#
#      home_season_shots_on_target          referee  home_team_yellow_cards  \
# 0                            145   Andre Marriner                       2
# 1                             98  Martin Atkinson                       2
# 2                            100     Kevin Friend                       1
# 3                            101        Mike Dean                       1
# 4                             77   Chris Kavanagh                       2
# ..                           ...              ...                     ...
# 375                          145  Martin Atkinson                       0
# 376                          145    Jonathan Moss                       3
# 377                          108      Lee Probert                       0
# 378                          124   Andre Marriner                       0
# 379                          102   Chris Kavanagh                       1
#
#      home_team_red_cards  away_team_yellow_cards away_team_red_cards  \
# 0                      0                       1                   0
# 1                      0                       2                   0
# 2                      0                       1                   0
# 3                      0                       2                   0
# 4                      0                       1                   0
# ..                   ...                     ...                 ...
# 375                    0                       2                   0
# 376                    0                       3                   0
# 377                    0                       1                   0
# 378                    0                       2                   0
# 379                    1                       0                   0
#
#     home_team_fouls  away_team_fouls  dirty
# 0                11                8      0
# 1                11               12      0
# 2                11                9      1
# 3                 9               11      1
# 4                 9                8      1
# ..              ...              ...    ...
# 375               3               11      0
# 376               9                6      0
# 377               8                6      0
# 378              10               13      0
# 379              10               10      0
#
# [380 rows x 40 columns]

# %%
matches_info_df[['home_team_shots', 'home_team_shots_on_target_original', 'home_team_shots_on_target_dirty']]
# Out:
#      home_team_shots  home_team_shots_on_target_original  \
# 0                  8                                   7
# 1                 11                                   3
# 2                 11                                   5
# 3                 11                                   7
# 4                  6                                   2
# ..               ...                                 ...
# 375               11                                   6
# 376               21                                  11
# 377                7                                   4
# 378                9                                   4
# 379               11                                   9
#
#      home_team_shots_on_target_dirty
# 0                                7.0
# 1                                3.0
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ..                               ...
# 375                              6.0
# 376                             11.0
# 377                              4.0
# 378                              4.0
# 379                              9.0
#
# [380 rows x 3 columns]

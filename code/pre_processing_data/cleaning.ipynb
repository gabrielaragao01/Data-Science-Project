# %%
import numpy as np
import pandas as pd

matches_info_df = pd.read_csv("matches_info_df.csv", index_col=0)
matches_info_df
# Out:
#      result  B365H     home_team_name  B365D           away_team_name  B365A  \
# 0         1   1.57  Manchester United   3.90           Leicester City   7.50
# 1        -1   3.90   Newcastle United   3.50        Tottenham Hotspur   2.04
# 2         2   1.90    AFC Bournemouth   3.60             Cardiff City   4.50
# 3        -2   2.50             Fulham   3.40           Crystal Palace   3.00
# 4        -3   6.50  Huddersfield Town   4.00                  Chelsea   1.61
# ..      ...    ...                ...    ...                      ...    ...
# 375       2   1.30          Liverpool   6.00  Wolverhampton Wanderers  11.00
# 376      -2   1.28  Manchester United   6.50             Cardiff City  11.00
# 377       0   1.44        Southampton   4.75        Huddersfield Town   8.50
# 378       0   2.20  Tottenham Hotspur   3.50                  Everton   3.50
# 379      -3   2.25            Watford   3.75          West Ham United   3.20
#
#      Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_team_goal_count  \
# 0                    0.00                  0.00                     2
# 1                    0.00                  0.00                     1
# 2                    0.00                  0.00                     2
# 3                    0.00                  0.00                     0
# 4                    0.00                  0.00                     0
# ..                    ...                   ...                   ...
# 375                  2.78                  1.28                     2
# 376                  2.00                  0.61                     0
# 377                  1.22                  0.33                     1
# 378                  2.06                  1.06                     2
# 379                  1.50                  1.00                     1
#
#      away_team_goal_count  ...  home_team_shots_on_target  \
# 0                       1  ...                        NaN
# 1                       2  ...                        3.0
# 2                       0  ...                        NaN
# 3                       2  ...                        NaN
# 4                       3  ...                        2.0
# ..                    ...  ...                        ...
# 375                     0  ...                        NaN
# 376                     2  ...                       11.0
# 377                     1  ...                        NaN
# 378                     2  ...                        4.0
# 379                     4  ...                        NaN
#
#      home_team_corner_count  away_team_shots  away_team_shots_on_target  \
# 0                         2                8                          5
# 1                         3               13                          6
# 2                         7                7                          2
# 3                         5               11                         11
# 4                         2                8                          5
# ..                      ...              ...                        ...
# 375                       4                7                          3
# 376                      11               11                          5
# 377                       4                8                          4
# 378                       7               13                         10
# 379                       7               15                         10
#
#     away_team_corner_count season_part  day_or_night  home-80-final  \
# 0                        5       first         Night           True
# 1                        5       first           Day          False
# 2                        4       first           Day           True
# 3                        5       first           Day          False
# 4                        5       first           Day          False
# ..                     ...         ...           ...            ...
# 375                      1        last           Day           True
# 376                      2        last           Day          False
# 377                      3        last           Day          False
# 378                      4        last           Day          False
# 379                      2        last           Day          False
#
#      away-80-final  80-final
# 0             True      True
# 1            False     False
# 2            False      True
# 3            False     False
# 4             True      True
# ..             ...       ...
# 375          False      True
# 376          False     False
# 377          False     False
# 378          False     False
# 379          False     False
#
# [380 rows x 27 columns]

# %%
## definição de tipos
matches_info_df.dtypes
# Out:
# result                                    int64
# B365H                                   float64
# home_team_name                           object
# B365D                                   float64
# away_team_name                           object
# B365A                                   float64
# Pre-Match PPG (Home)                    float64
# Pre-Match PPG (Away)                    float64
# home_team_goal_count                      int64
# away_team_goal_count                      int64
# home_team_goal_count_half_time            int64
# home_team_goal_count_secondhalf_time      int64
# away_team_goal_count_half_time            int64
# away_team_goal_count_secondhalf_time      int64
# home_team_goal_timings                   object
# away_team_goal_timings                   object
# home_team_shots                           int64
# home_team_shots_on_target               float64
# home_team_corner_count                    int64
# away_team_shots                           int64
# away_team_shots_on_target                 int64
# away_team_corner_count                    int64
# season_part                              object
# day_or_night                             object
# home-80-final                              bool
# away-80-final                              bool
# 80-final                                   bool
# dtype: object

# %%
#ajustando tipos dos dados
# digo digo e bieli, home_team_goal_timings still being an object cause is not a category, 
# we can not say that cause 43 min goal is not a category, there wont be a category just to 43 min goasl

matches_info_df['home_team_name'] = matches_info_df['home_team_name'].astype('category')
matches_info_df['away_team_name'] = matches_info_df['away_team_name'].astype('category')
matches_info_df['season_part'] = matches_info_df['season_part'].astype('category')
matches_info_df['day_or_night'] = matches_info_df['day_or_night'].astype('category')
matches_info_df['home-80-final'] = matches_info_df['home-80-final'].astype('category')
matches_info_df['away-80-final'] = matches_info_df['away-80-final'].astype('category')
matches_info_df['80-final'] = matches_info_df['80-final'].astype('category')
matches_info_df.dtypes
# Out:
# result                                     int64
# B365H                                    float64
# home_team_name                          category
# B365D                                    float64
# away_team_name                          category
# B365A                                    float64
# Pre-Match PPG (Home)                     float64
# Pre-Match PPG (Away)                     float64
# home_team_goal_count                       int64
# away_team_goal_count                       int64
# home_team_goal_count_half_time             int64
# home_team_goal_count_secondhalf_time       int64
# away_team_goal_count_half_time             int64
# away_team_goal_count_secondhalf_time       int64
# home_team_goal_timings                    object
# away_team_goal_timings                    object
# home_team_shots                            int64
# home_team_shots_on_target                float64
# home_team_corner_count                     int64
# away_team_shots                            int64
# away_team_shots_on_target                  int64
# away_team_corner_count                     int64
# season_part                             category
# day_or_night                            category
# home-80-final                           category
# away-80-final                           category
# 80-final                                category
# dtype: object

# %%
print(matches_info_df['home_team_name'].cat.categories)
print(len(matches_info_df['home_team_name'].cat.categories))
# Out:
# Index(['AFC Bournemouth', 'Arsenal', 'Brighton & Hove Albion', 'Burnley',
#        'Cardiff City', 'Chelsea', 'Crystal Palace', 'Everton', 'Fulham',
#        'Huddersfield Town', 'Leicester City', 'Liverpool', 'Manchester City',
#        'Manchester United', 'Newcastle United', 'Southampton',
#        'Tottenham Hotspur', 'Watford', 'West Ham United',
#        'Wolverhampton Wanderers'],
#       dtype='object')
# 20

# %%
print(matches_info_df['away_team_name'].cat.categories)
print(len(matches_info_df['away_team_name'].cat.categories))
# Out:
# Index(['AFC Bournemouth', 'Arsenal', 'Brighton & Hove Albion', 'Burnley',
#        'Cardiff City', 'Chelsea', 'Crystal Palace', 'Everton', 'Fulham',
#        'Huddersfield Town', 'Leicester City', 'Liverpool', 'Manchester City',
#        'Manchester United', 'Newcastle United', 'Southampton',
#        'Tottenham Hotspur', 'Watford', 'West Ham United',
#        'Wolverhampton Wanderers'],
#       dtype='object')
# 20

# %%
# Usando pd.factorize() para obter os códigos com base na ordem de aparição, usando o cat codes ele tava vindo com uma ordem 0, 2, 1
codes, unique = pd.factorize(matches_info_df['season_part'])

# Convertendo os códigos para int8
matches_info_df['season_part'] = codes.astype('int8')

matches_info_df['home_team_name'] = matches_info_df['home_team_name'].cat.codes
matches_info_df['away_team_name'] = matches_info_df['away_team_name'].cat.codes
matches_info_df['day_or_night'] = matches_info_df['day_or_night'].cat.codes
matches_info_df['home-80-final'] = matches_info_df['home-80-final'].cat.codes
matches_info_df['away-80-final'] = matches_info_df['away-80-final'].cat.codes
matches_info_df['80-final'] = matches_info_df['80-final'].cat.codes

# dropping timmings to do the correlation pearson perguntar a prof se ta correto
matches_info_df = matches_info_df.drop(['home_team_goal_timings', 'away_team_goal_timings'], axis=1)


matches_info_df.dtypes
# Out:
# result                                    int64
# B365H                                   float64
# home_team_name                             int8
# B365D                                   float64
# away_team_name                             int8
# B365A                                   float64
# Pre-Match PPG (Home)                    float64
# Pre-Match PPG (Away)                    float64
# home_team_goal_count                      int64
# away_team_goal_count                      int64
# home_team_goal_count_half_time            int64
# home_team_goal_count_secondhalf_time      int64
# away_team_goal_count_half_time            int64
# away_team_goal_count_secondhalf_time      int64
# home_team_shots                           int64
# home_team_shots_on_target               float64
# home_team_corner_count                    int64
# away_team_shots                           int64
# away_team_shots_on_target                 int64
# away_team_corner_count                    int64
# season_part                                int8
# day_or_night                               int8
# home-80-final                              int8
# away-80-final                              int8
# 80-final                                   int8
# dtype: object

# %%
matches_info_df
# Out:
#      result  B365H  home_team_name  B365D  away_team_name  B365A  \
# 0         1   1.57              13   3.90              10   7.50
# 1        -1   3.90              14   3.50              16   2.04
# 2         2   1.90               0   3.60               4   4.50
# 3        -2   2.50               8   3.40               6   3.00
# 4        -3   6.50               9   4.00               5   1.61
# ..      ...    ...             ...    ...             ...    ...
# 375       2   1.30              11   6.00              19  11.00
# 376      -2   1.28              13   6.50               4  11.00
# 377       0   1.44              15   4.75               9   8.50
# 378       0   2.20              16   3.50               7   3.50
# 379      -3   2.25              17   3.75              18   3.20
#
#      Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_team_goal_count  \
# 0                    0.00                  0.00                     2
# 1                    0.00                  0.00                     1
# 2                    0.00                  0.00                     2
# 3                    0.00                  0.00                     0
# 4                    0.00                  0.00                     0
# ..                    ...                   ...                   ...
# 375                  2.78                  1.28                     2
# 376                  2.00                  0.61                     0
# 377                  1.22                  0.33                     1
# 378                  2.06                  1.06                     2
# 379                  1.50                  1.00                     1
#
#      away_team_goal_count  ...  home_team_shots_on_target  \
# 0                       1  ...                        NaN
# 1                       2  ...                        3.0
# 2                       0  ...                        NaN
# 3                       2  ...                        NaN
# 4                       3  ...                        2.0
# ..                    ...  ...                        ...
# 375                     0  ...                        NaN
# 376                     2  ...                       11.0
# 377                     1  ...                        NaN
# 378                     2  ...                        4.0
# 379                     4  ...                        NaN
#
#      home_team_corner_count  away_team_shots  away_team_shots_on_target  \
# 0                         2                8                          5
# 1                         3               13                          6
# 2                         7                7                          2
# 3                         5               11                         11
# 4                         2                8                          5
# ..                      ...              ...                        ...
# 375                       4                7                          3
# 376                      11               11                          5
# 377                       4                8                          4
# 378                       7               13                         10
# 379                       7               15                         10
#
#      away_team_corner_count  season_part  day_or_night  home-80-final  \
# 0                         5            0             1              1
# 1                         5            0             0              0
# 2                         4            0             0              1
# 3                         5            0             0              0
# 4                         5            0             0              0
# ..                      ...          ...           ...            ...
# 375                       1            2             0              1
# 376                       2            2             0              0
# 377                       3            2             0              0
# 378                       4            2             0              0
# 379                       2            2             0              0
#
#      away-80-final  80-final
# 0                1         1
# 1                0         0
# 2                0         1
# 3                0         0
# 4                1         1
# ..             ...       ...
# 375              0         1
# 376              0         0
# 377              0         0
# 378              0         0
# 379              0         0
#
# [380 rows x 25 columns]

# %%
print(matches_info_df.isnull().sum())

# colunas vazias que aparecem no timing é times que nao fizeram gols na partida
# como os dados realmente vazios sao da coluna de chutes na barra, podemos tentar definilos por meios estatisticos
# explicar por que nao faria sentido fazer os metodos que o professor fala, ex dropar a coluna ou estimar pela media
# Out:
# result                                    0
# B365H                                     0
# home_team_name                            0
# B365D                                     0
# away_team_name                            0
# B365A                                     0
# Pre-Match PPG (Home)                      0
# Pre-Match PPG (Away)                      0
# home_team_goal_count                      0
# away_team_goal_count                      0
# home_team_goal_count_half_time            0
# home_team_goal_count_secondhalf_time      0
# away_team_goal_count_half_time            0
# away_team_goal_count_secondhalf_time      0
# home_team_shots                           0
# home_team_shots_on_target               190
# home_team_corner_count                    0
# away_team_shots                           0
# away_team_shots_on_target                 0
# away_team_corner_count                    0
# season_part                               0
# day_or_night                              0
# home-80-final                             0
# away-80-final                             0
# 80-final                                  0
# dtype: int64

# %%
matches_info_df.corr(method='spearman')
# Out:
#                                         result     B365H  home_team_name  \
# result                                1.000000 -0.534834        0.043822
# B365H                                -0.534834  1.000000       -0.117895
# home_team_name                        0.043822 -0.117895        1.000000
# B365D                                 0.195266 -0.343922        0.042354
# away_team_name                       -0.131597  0.141048       -0.052632
# B365A                                 0.529997 -0.996954        0.118228
# Pre-Match PPG (Home)                  0.273234 -0.475464       -0.028216
# Pre-Match PPG (Away)                 -0.196324  0.513770        0.001041
# home_team_goal_count                  0.807843 -0.422411        0.049851
# away_team_goal_count                 -0.700826  0.384664        0.000039
# home_team_goal_count_half_time        0.518109 -0.290450       -0.009970
# home_team_goal_count_secondhalf_time  0.616103 -0.337587        0.076738
# away_team_goal_count_half_time       -0.454234  0.288700       -0.008275
# away_team_goal_count_secondhalf_time -0.547371  0.250559       -0.012507
# home_team_shots                       0.372580 -0.474998        0.074624
# home_team_shots_on_target             0.534507 -0.521328        0.069407
# home_team_corner_count                0.146393 -0.398645        0.023927
# away_team_shots                      -0.343054  0.424244       -0.072115
# away_team_shots_on_target            -0.472398  0.382638       -0.025898
# away_team_corner_count               -0.114863  0.381534       -0.047096
# season_part                           0.036040 -0.015941        0.007434
# day_or_night                          0.007033  0.033427        0.066765
# home-80-final                         0.366115 -0.245708       -0.006038
# away-80-final                        -0.340302  0.227900        0.031027
# 80-final                              0.081032 -0.036424        0.017930
#
#                                          B365D  away_team_name     B365A  \
# result                                0.195266       -0.131597  0.529997
# B365H                                -0.343922        0.141048 -0.996954
# home_team_name                        0.042354       -0.052632  0.118228
# B365D                                 1.000000       -0.084061  0.320255
# away_team_name                       -0.084061        1.000000 -0.140501
# B365A                                 0.320255       -0.140501  1.000000
# Pre-Match PPG (Home)                  0.446829        0.010267  0.453351
# Pre-Match PPG (Away)                  0.107441        0.220024 -0.533720
# home_team_goal_count                  0.196557       -0.139897  0.416232
# away_team_goal_count                 -0.077229        0.031197 -0.384412
# home_team_goal_count_half_time        0.095605       -0.123908  0.290142
# home_team_goal_count_secondhalf_time  0.214348       -0.084311  0.328833
# away_team_goal_count_half_time       -0.028518        0.030801 -0.290683
# away_team_goal_count_secondhalf_time -0.076657        0.009258 -0.248832
# home_team_shots                       0.124951       -0.139706  0.475246
# home_team_shots_on_target             0.246508       -0.140012  0.514294
# home_team_corner_count                0.053787       -0.107753  0.401184
# away_team_shots                      -0.098556        0.106575 -0.430546
# away_team_shots_on_target            -0.059434        0.086981 -0.390992
# away_team_corner_count               -0.113319        0.081894 -0.381700
# season_part                           0.080344       -0.003724  0.005432
# day_or_night                          0.021780        0.034426 -0.034552
# home-80-final                         0.176026        0.002013  0.241083
# away-80-final                        -0.024568        0.007610 -0.227504
# 80-final                              0.126274        0.015172  0.031905
#
#                                       Pre-Match PPG (Home)  \
# result                                            0.273234
# B365H                                            -0.475464
# home_team_name                                   -0.028216
# B365D                                             0.446829
# away_team_name                                    0.010267
# B365A                                             0.453351
# Pre-Match PPG (Home)                              1.000000
# Pre-Match PPG (Away)                              0.218623
# home_team_goal_count                              0.250378
# away_team_goal_count                             -0.178547
# home_team_goal_count_half_time                    0.128210
# home_team_goal_count_secondhalf_time              0.227653
# away_team_goal_count_half_time                   -0.137493
# away_team_goal_count_secondhalf_time             -0.111493
# home_team_shots                                   0.155004
# home_team_shots_on_target                         0.262598
# home_team_corner_count                            0.148545
# away_team_shots                                  -0.235503
# away_team_shots_on_target                        -0.186917
# away_team_corner_count                           -0.195560
# season_part                                       0.152640
# day_or_night                                      0.108767
# home-80-final                                     0.109869
# away-80-final                                    -0.148220
# 80-final                                         -0.015043
#
#                                       Pre-Match PPG (Away)  \
# result                                           -0.196324
# B365H                                             0.513770
# home_team_name                                    0.001041
# B365D                                             0.107441
# away_team_name                                    0.220024
# B365A                                            -0.533720
# Pre-Match PPG (Home)                              0.218623
# Pre-Match PPG (Away)                              1.000000
# home_team_goal_count                             -0.133620
# away_team_goal_count                              0.150759
# home_team_goal_count_half_time                   -0.160057
# home_team_goal_count_secondhalf_time             -0.053865
# away_team_goal_count_half_time                    0.085827
# away_team_goal_count_secondhalf_time              0.110863
# home_team_shots                                  -0.275323
# home_team_shots_on_target                        -0.152849
# home_team_corner_count                           -0.209002
# away_team_shots                                   0.182516
# away_team_shots_on_target                         0.119019
# away_team_corner_count                            0.217743
# season_part                                       0.092004
# day_or_night                                      0.118895
# home-80-final                                    -0.057794
# away-80-final                                     0.059732
# 80-final                                         -0.007593
#
#                                       home_team_goal_count  \
# result                                            0.807843
# B365H                                            -0.422411
# home_team_name                                    0.049851
# B365D                                             0.196557
# away_team_name                                   -0.139897
# B365A                                             0.416232
# Pre-Match PPG (Home)                              0.250378
# Pre-Match PPG (Away)                             -0.133620
# home_team_goal_count                              1.000000
# away_team_goal_count                             -0.179616
# home_team_goal_count_half_time                    0.653076
# home_team_goal_count_secondhalf_time              0.757303
# away_team_goal_count_half_time                   -0.098859
# away_team_goal_count_secondhalf_time             -0.165414
# home_team_shots                                   0.390270
# home_team_shots_on_target                         0.572125
# home_team_corner_count                            0.083770
# away_team_shots                                  -0.178779
# away_team_shots_on_target                        -0.227419
# away_team_corner_count                           -0.120817
# season_part                                       0.040120
# day_or_night                                      0.050840
# home-80-final                                     0.436308
# away-80-final                                    -0.118752
# 80-final                                          0.267579
#
#                                       away_team_goal_count  ...  \
# result                                           -0.700826  ...
# B365H                                             0.384664  ...
# home_team_name                                    0.000039  ...
# B365D                                            -0.077229  ...
# away_team_name                                    0.031197  ...
# B365A                                            -0.384412  ...
# Pre-Match PPG (Home)                             -0.178547  ...
# Pre-Match PPG (Away)                              0.150759  ...
# home_team_goal_count                             -0.179616  ...
# away_team_goal_count                              1.000000  ...
# home_team_goal_count_half_time                   -0.098914  ...
# home_team_goal_count_secondhalf_time             -0.145838  ...
# away_team_goal_count_half_time                    0.679236  ...
# away_team_goal_count_secondhalf_time              0.729338  ...
# home_team_shots                                  -0.160887  ...
# home_team_shots_on_target                        -0.173327  ...
# home_team_corner_count                           -0.139797  ...
# away_team_shots                                   0.356809  ...
# away_team_shots_on_target                         0.532229  ...
# away_team_corner_count                            0.056907  ...
# season_part                                      -0.047223  ...
# day_or_night                                      0.037180  ...
# home-80-final                                    -0.099061  ...
# away-80-final                                     0.448928  ...
# 80-final                                          0.192127  ...
#
#                                       home_team_shots_on_target  \
# result                                                 0.534507
# B365H                                                 -0.521328
# home_team_name                                         0.069407
# B365D                                                  0.246508
# away_team_name                                        -0.140012
# B365A                                                  0.514294
# Pre-Match PPG (Home)                                   0.262598
# Pre-Match PPG (Away)                                  -0.152849
# home_team_goal_count                                   0.572125
# away_team_goal_count                                  -0.173327
# home_team_goal_count_half_time                         0.390230
# home_team_goal_count_secondhalf_time                   0.477578
# away_team_goal_count_half_time                        -0.121896
# away_team_goal_count_secondhalf_time                  -0.158797
# home_team_shots                                        0.725415
# home_team_shots_on_target                              1.000000
# home_team_corner_count                                 0.363107
# away_team_shots                                       -0.260606
# away_team_shots_on_target                             -0.204487
# away_team_corner_count                                -0.296022
# season_part                                            0.071704
# day_or_night                                           0.021484
# home-80-final                                          0.261503
# away-80-final                                         -0.139085
# 80-final                                               0.108072
#
#                                       home_team_corner_count  away_team_shots  \
# result                                              0.146393        -0.343054
# B365H                                              -0.398645         0.424244
# home_team_name                                      0.023927        -0.072115
# B365D                                               0.053787        -0.098556
# away_team_name                                     -0.107753         0.106575
# B365A                                               0.401184        -0.430546
# Pre-Match PPG (Home)                                0.148545        -0.235503
# Pre-Match PPG (Away)                               -0.209002         0.182516
# home_team_goal_count                                0.083770        -0.178779
# away_team_goal_count                               -0.139797         0.356809
# home_team_goal_count_half_time                     -0.075708        -0.089201
# home_team_goal_count_secondhalf_time                0.172722        -0.165692
# away_team_goal_count_half_time                     -0.099058         0.212490
# away_team_goal_count_secondhalf_time               -0.109163         0.296137
# home_team_shots                                     0.517106        -0.377294
# home_team_shots_on_target                           0.363107        -0.260606
# home_team_corner_count                              1.000000        -0.358642
# away_team_shots                                    -0.358642         1.000000
# away_team_shots_on_target                          -0.273023         0.739508
# away_team_corner_count                             -0.372533         0.455624
# season_part                                         0.027679        -0.031481
# day_or_night                                       -0.076942        -0.020978
# home-80-final                                       0.084485        -0.128426
# away-80-final                                      -0.062903         0.217154
# 80-final                                            0.041722         0.038219
#
#                                       away_team_shots_on_target  \
# result                                                -0.472398
# B365H                                                  0.382638
# home_team_name                                        -0.025898
# B365D                                                 -0.059434
# away_team_name                                         0.086981
# B365A                                                 -0.390992
# Pre-Match PPG (Home)                                  -0.186917
# Pre-Match PPG (Away)                                   0.119019
# home_team_goal_count                                  -0.227419
# away_team_goal_count                                   0.532229
# home_team_goal_count_half_time                        -0.129609
# home_team_goal_count_secondhalf_time                  -0.183733
# away_team_goal_count_half_time                         0.380309
# away_team_goal_count_secondhalf_time                   0.390371
# home_team_shots                                       -0.298153
# home_team_shots_on_target                             -0.204487
# home_team_corner_count                                -0.273023
# away_team_shots                                        0.739508
# away_team_shots_on_target                              1.000000
# away_team_corner_count                                 0.274747
# season_part                                           -0.071957
# day_or_night                                          -0.038593
# home-80-final                                         -0.140265
# away-80-final                                          0.257498
# 80-final                                               0.052038
#
#                                       away_team_corner_count  season_part  \
# result                                             -0.114863     0.036040
# B365H                                               0.381534    -0.015941
# home_team_name                                     -0.047096     0.007434
# B365D                                              -0.113319     0.080344
# away_team_name                                      0.081894    -0.003724
# B365A                                              -0.381700     0.005432
# Pre-Match PPG (Home)                               -0.195560     0.152640
# Pre-Match PPG (Away)                                0.217743     0.092004
# home_team_goal_count                               -0.120817     0.040120
# away_team_goal_count                                0.056907    -0.047223
# home_team_goal_count_half_time                     -0.005643    -0.020787
# home_team_goal_count_secondhalf_time               -0.182588     0.074155
# away_team_goal_count_half_time                     -0.016520    -0.022886
# away_team_goal_count_secondhalf_time                0.103087    -0.014486
# home_team_shots                                    -0.427943    -0.003018
# home_team_shots_on_target                          -0.296022     0.071704
# home_team_corner_count                             -0.372533     0.027679
# away_team_shots                                     0.455624    -0.031481
# away_team_shots_on_target                           0.274747    -0.071957
# away_team_corner_count                              1.000000    -0.046155
# season_part                                        -0.046155     1.000000
# day_or_night                                       -0.005990     0.171094
# home-80-final                                      -0.101723     0.033250
# away-80-final                                       0.106799     0.019115
# 80-final                                           -0.024551     0.024172
#
#                                       day_or_night  home-80-final  \
# result                                    0.007033       0.366115
# B365H                                     0.033427      -0.245708
# home_team_name                            0.066765      -0.006038
# B365D                                     0.021780       0.176026
# away_team_name                            0.034426       0.002013
# B365A                                    -0.034552       0.241083
# Pre-Match PPG (Home)                      0.108767       0.109869
# Pre-Match PPG (Away)                      0.118895      -0.057794
# home_team_goal_count                      0.050840       0.436308
# away_team_goal_count                      0.037180      -0.099061
# home_team_goal_count_half_time            0.044359       0.083712
# home_team_goal_count_secondhalf_time     -0.015642       0.549114
# away_team_goal_count_half_time            0.059885      -0.093377
# away_team_goal_count_secondhalf_time     -0.025863      -0.054507
# home_team_shots                           0.023233       0.213796
# home_team_shots_on_target                 0.021484       0.261503
# home_team_corner_count                   -0.076942       0.084485
# away_team_shots                          -0.020978      -0.128426
# away_team_shots_on_target                -0.038593      -0.140265
# away_team_corner_count                   -0.005990      -0.101723
# season_part                               0.171094       0.033250
# day_or_night                              1.000000      -0.071206
# home-80-final                            -0.071206       1.000000
# away-80-final                             0.056938      -0.097547
# 80-final                                 -0.025069       0.720852
#
#                                       away-80-final  80-final
# result                                    -0.340302  0.081032
# B365H                                      0.227900 -0.036424
# home_team_name                             0.031027  0.017930
# B365D                                     -0.024568  0.126274
# away_team_name                             0.007610  0.015172
# B365A                                     -0.227504  0.031905
# Pre-Match PPG (Home)                      -0.148220 -0.015043
# Pre-Match PPG (Away)                       0.059732 -0.007593
# home_team_goal_count                      -0.118752  0.267579
# away_team_goal_count                       0.448928  0.192127
# home_team_goal_count_half_time            -0.072608  0.029445
# home_team_goal_count_secondhalf_time      -0.104711  0.360919
# away_team_goal_count_half_time             0.042860 -0.044287
# away_team_goal_count_secondhalf_time       0.579906  0.310434
# home_team_shots                           -0.109148  0.118169
# home_team_shots_on_target                 -0.139085  0.108072
# home_team_corner_count                    -0.062903  0.041722
# away_team_shots                            0.217154  0.038219
# away_team_shots_on_target                  0.257498  0.052038
# away_team_corner_count                     0.106799 -0.024551
# season_part                                0.019115  0.024172
# day_or_night                               0.056938 -0.025069
# home-80-final                             -0.097547  0.720852
# away-80-final                              1.000000  0.541354
# 80-final                                   0.541354  1.000000
#
# [25 rows x 25 columns]

# %%
import numpy as np
import pandas as pd

matches_info_df = pd.read_csv("matches_info_df.csv", index_col=0)
matches_info_df
# Out:
#                   date_GMT  B365H     home_team_name  B365D  \
# 0     Aug 10 2018 - 7:00pm   1.57  Manchester United   3.90
# 1    Aug 11 2018 - 11:30am   3.90   Newcastle United   3.50
# 2     Aug 11 2018 - 2:00pm   1.90    AFC Bournemouth   3.60
# 3     Aug 11 2018 - 2:00pm   2.50             Fulham   3.40
# 4     Aug 11 2018 - 2:00pm   6.50  Huddersfield Town   4.00
# ..                     ...    ...                ...    ...
# 375   May 12 2019 - 2:00pm   1.30          Liverpool   6.00
# 376   May 12 2019 - 2:00pm   1.28  Manchester United   6.50
# 377   May 12 2019 - 2:00pm   1.44        Southampton   4.75
# 378   May 12 2019 - 2:00pm   2.20  Tottenham Hotspur   3.50
# 379   May 12 2019 - 2:00pm   2.25            Watford   3.75
#
#               away_team_name  B365A  Pre-Match PPG (Home)  \
# 0             Leicester City   7.50                  0.00
# 1          Tottenham Hotspur   2.04                  0.00
# 2               Cardiff City   4.50                  0.00
# ...

# %%
## definição de tipos
matches_info_df.dtypes
# Out:
# date_GMT                           object
# B365H                             float64
# home_team_name                     object
# B365D                             float64
# away_team_name                     object
# B365A                             float64
# Pre-Match PPG (Home)              float64
# Pre-Match PPG (Away)              float64
# home_team_goal_count                int64
# away_team_goal_count                int64
# home_team_goal_count_half_time      int64
# away_team_goal_count_half_time      int64
# home_team_goal_timings             object
# away_team_goal_timings             object
# home_team_shots                     int64
# home_team_shots_on_target           int64
# away_team_shots                     int64
# away_team_shots_on_target           int64
# dtype: object

# %%
#ajustando tipos dos dados
matches_info_df['suburb'] = matches_info_df['suburb'].astype('category')
matches_info_df['district'] = matches_info_df['district'].astype('category')
matches_info_df['city'] = matches_info_df['city'].astype('category')
matches_info_df['state'] = matches_info_df['state'].astype('category')
matches_info_df['type'] = matches_info_df['type'].astype('category')

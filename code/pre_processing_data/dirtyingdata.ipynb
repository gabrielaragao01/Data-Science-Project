# %%
import pandas as pd
import numpy as np

# %%
matches_info_df = pd.read_csv("matches_info_df.csv", index_col=0)
matches_info_df
# Out:
#      B365H     home_team_name  B365D           away_team_name  B365A  \
# 0     1.57  Manchester United   3.90           Leicester City   7.50
# 1     3.90   Newcastle United   3.50        Tottenham Hotspur   2.04
# 2     1.90    AFC Bournemouth   3.60             Cardiff City   4.50
# 3     2.50             Fulham   3.40           Crystal Palace   3.00
# 4     6.50  Huddersfield Town   4.00                  Chelsea   1.61
# ..     ...                ...    ...                      ...    ...
# 375   1.30          Liverpool   6.00  Wolverhampton Wanderers  11.00
# 376   1.28  Manchester United   6.50             Cardiff City  11.00
# 377   1.44        Southampton   4.75        Huddersfield Town   8.50
# 378   2.20  Tottenham Hotspur   3.50                  Everton   3.50
# 379   2.25            Watford   3.75          West Ham United   3.20
#
#      Pre-Match PPG (Home)  Pre-Match PPG (Away)  home_team_goal_count  \
# ...

# %%
porcentagem = 0.5
num_linhas = len(matches_info_df)
num_valores_para_sujar = int(num_linhas * porcentagem)

coluna = 'home_team_shots'

indices_para_sujar = np.random.choice(matches_info_df.index, num_valores_para_sujar, replace=False)

matches_info_df.loc[indices_para_sujar, coluna] = np.nan

num_nans = matches_info_df['home_team_shots'].isna().sum()

matches_info_df.head(50)
# Out:
#     B365H           home_team_name  B365D           away_team_name  B365A  \
# 0    1.57        Manchester United   3.90           Leicester City   7.50
# 1    3.90         Newcastle United   3.50        Tottenham Hotspur   2.04
# 2    1.90          AFC Bournemouth   3.60             Cardiff City   4.50
# 3    2.50                   Fulham   3.40           Crystal Palace   3.00
# 4    6.50        Huddersfield Town   4.00                  Chelsea   1.61
# 5    2.37                  Watford   3.20   Brighton & Hove Albion   3.40
# 6    2.37  Wolverhampton Wanderers   3.30                  Everton   3.30
# 7    1.25                Liverpool   6.50          West Ham United  14.00
# 8    1.85              Southampton   3.50                  Burnley   5.00
# 9    4.00                  Arsenal   3.80          Manchester City   1.95
# 10   3.25             Cardiff City   3.10         Newcastle United   2.54
# 11   1.90                  Everton   3.50              Southampton   4.75
# ...
